# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.metrics import plot_confusion_matrix
from sklearn import metrics
import seaborn as sns
sns.set()
import matplotlib.pyplot as plt
# %matplotlib inline
plt.style.use('ggplot')

# %%
data = pd.read_csv('heart_failure_clinical_records_dataset.train.csv')


data
# Out:
#      DEATH_EVENT     age  anaemia  creatinine_phosphokinase  diabetes  \
# 0              1  75.000        1                       246         0
# 1              1  75.000        0                        99         0
# 2              1  60.667        1                       104         1
# 3              0  52.000        0                       132         0
# 4              1  94.000        0                       582         1
# ..           ...     ...      ...                       ...       ...
# 234            0  60.667        1                       151         1
# 235            0  58.000        0                       582         1
# 236            0  55.000        0                       748         0
# 237            0  44.000        0                       582         1
# 238            0  80.000        0                       898         0
#
#      ejection_fraction  high_blood_pressure  platelets  serum_creatinine  \
# 0                   15                    0  127000.00              1.20
# 1                   38                    1  224000.00              2.50
# 2                   30                    0  389000.00              1.50
# 3                   30                    0  218000.00              0.70
# 4                   38                    1  263358.03              1.83
# ..                 ...                  ...        ...               ...
# 234                 40                    1  201000.00              1.00
# 235                 35                    0  122000.00              0.90
# 236                 45                    0  263000.00              1.30
# 237                 30                    1  263358.03              1.60
# 238                 25                    0  149000.00              1.10
#
#      serum_sodium  sex  smoking  time
# 0             137    1        0    10
# 1             134    1        0   162
# 2             136    1        0   171
# 3             136    1        1   112
# 4             134    1        0    27
# ..            ...  ...      ...   ...
# 234           136    0        0   172
# 235           139    1        1    71
# 236           137    1        0    88
# 237           130    1        1   244
# 238           144    1        1    87
#
# [239 rows x 13 columns]

# %%
y = data['DEATH_EVENT']
y
# Out:
# 0      1
# 1      1
# 2      1
# 3      0
# 4      1
#       ..
# 234    0
# 235    0
# 236    0
# 237    0
# 238    0
# Name: DEATH_EVENT, Length: 239, dtype: int64

# %%
X= data.drop('DEATH_EVENT',axis=1)
X
# Out:
#         age  anaemia  creatinine_phosphokinase  diabetes  ejection_fraction  \
# 0    75.000        1                       246         0                 15
# 1    75.000        0                        99         0                 38
# 2    60.667        1                       104         1                 30
# 3    52.000        0                       132         0                 30
# 4    94.000        0                       582         1                 38
# ..      ...      ...                       ...       ...                ...
# 234  60.667        1                       151         1                 40
# 235  58.000        0                       582         1                 35
# 236  55.000        0                       748         0                 45
# 237  44.000        0                       582         1                 30
# 238  80.000        0                       898         0                 25
#
#      high_blood_pressure  platelets  serum_creatinine  serum_sodium  sex  \
# 0                      0  127000.00              1.20           137    1
# 1                      1  224000.00              2.50           134    1
# 2                      0  389000.00              1.50           136    1
# 3                      0  218000.00              0.70           136    1
# 4                      1  263358.03              1.83           134    1
# ..                   ...        ...               ...           ...  ...
# 234                    1  201000.00              1.00           136    0
# 235                    0  122000.00              0.90           139    1
# 236                    0  263000.00              1.30           137    1
# 237                    1  263358.03              1.60           130    1
# 238                    0  149000.00              1.10           144    1
#
#      smoking  time
# 0          0    10
# 1          0   162
# 2          0   171
# 3          1   112
# 4          0    27
# ..       ...   ...
# 234        0   172
# 235        1    71
# 236        0    88
# 237        1   244
# 238        1    87
#
# [239 rows x 12 columns]

# %%
#Train/Test Split
train_X, test_X, train_y, test_y = train_test_split(X, y, test_size = 0.2)

# %%
train_X.insert(0,train_y.name,train_y)
train_X
# Out:
#      DEATH_EVENT   age  anaemia  creatinine_phosphokinase  diabetes  \
# 215            0  70.0        0                       835         0
# 87             0  79.0        1                        55         0
# 62             0  40.0        0                       478         1
# 123            0  45.0        1                        66         1
# 185            1  73.0        0                       582         0
# ..           ...   ...      ...                       ...       ...
# 210            1  68.0        1                       577         0
# 85             1  69.0        0                       582         0
# 18             0  45.0        0                      2060         1
# 46             1  70.0        1                       125         0
# 207            0  60.0        0                       253         0
#
#      ejection_fraction  high_blood_pressure  platelets  serum_creatinine  \
# 215                 35                    1  305000.00              0.80
# 87                  50                    1  172000.00              1.80
# 62                  30                    0  303000.00              0.90
# 123                 25                    0  233000.00              0.80
# 185                 20                    0  263358.03              1.83
# ..                 ...                  ...        ...               ...
# 210                 25                    1  166000.00              1.00
# 85                  20                    0  266000.00              1.20
# 18                  60                    0  742000.00              0.80
# 46                  25                    1  237000.00              1.00
# 207                 35                    0  279000.00              1.70
#
#      serum_sodium  sex  smoking  time
# 215           133    0        0   145
# 87            133    1        0    78
# 62            136    1        0   148
# 123           135    1        0   230
# 185           134    1        0   198
# ..            ...  ...      ...   ...
# 210           138    1        0    43
# 85            134    1        1    73
# 18            138    0        0   278
# 46            140    0        0    15
# 207           140    1        0   250
#
# [191 rows x 13 columns]

# %%
test_X.insert(0,test_y.name, test_y)
test_X
# Out:
#      DEATH_EVENT   age  anaemia  creatinine_phosphokinase  diabetes  \
# 119            1  75.0        0                       582         0
# 138            1  65.0        1                       160         1
# 10             1  46.0        0                       168         1
# 49             1  80.0        0                       776         1
# 74             0  42.0        0                        64         0
# 48             0  63.0        1                       514         1
# 124            0  70.0        0                        88         1
# 45             0  60.0        1                       754         1
# 127            1  90.0        1                        60         1
# 1              1  75.0        0                        99         0
# 162            0  53.0        0                        63         1
# 107            1  53.0        1                        91         0
# 33             1  82.0        1                       855         1
# 24             0  70.0        0                        66         1
# 178            0  67.0        0                       213         0
# 102            1  58.0        1                        60         0
# 129            1  72.0        0                       233         0
# 96             0  45.0        0                       582         1
# 132            0  70.0        0                        81         1
# 16             0  75.0        1                       203         1
# 56             0  50.0        0                      1548         0
# 29             0  50.0        0                       250         0
# 37             0  40.0        0                       582         1
# 14             0  85.0        1                       910         0
# 194            1  57.0        1                       129         0
# 25             0  46.0        0                       719         0
# 233            0  65.0        1                        52         0
# 120            0  56.0        1                       135         1
# 75             0  65.0        0                       118         0
# 104            0  72.0        0                       211         0
# 88             0  62.0        1                       655         0
# 6              0  53.0        1                       446         0
# 86             1  82.0        0                        70         1
# 15             0  75.0        0                       675         1
# 187            1  50.0        1                       111         0
# 131            0  63.0        1                      1767         0
# 4              1  94.0        0                       582         1
# 47             0  55.0        0                       835         0
# 128            1  50.0        0                       318         0
# 105            0  55.0        0                        84         1
# 106            0  65.0        0                       582         1
# 58             0  78.0        1                        64         0
# 99             0  59.0        1                       129         0
# 179            0  45.0        0                       308         1
# 90             0  45.0        0                       582         1
# 143            0  58.0        1                        57         0
# 171            0  50.0        1                        54         0
# 39             0  75.0        0                       582         0
#
#      ejection_fraction  high_blood_pressure  platelets  serum_creatinine  \
# 119                 20                    1  265000.00              1.90
# 138                 20                    0  327000.00              2.70
# 10                  17                    1  271000.00              2.10
# 49                  38                    1  192000.00              1.30
# 74                  40                    0  189000.00              0.70
# 48                  25                    1  254000.00              1.30
# 124                 35                    1  236000.00              1.20
# 45                  40                    1  328000.00              1.20
# 127                 50                    0  226000.00              1.00
# 1                   38                    1  224000.00              2.50
# 162                 60                    0  368000.00              0.80
# 107                 20                    1  418000.00              1.40
# 33                  50                    1  321000.00              1.00
# 24                  45                    0  249000.00              0.80
# 178                 38                    0  215000.00              1.20
# 102                 38                    0  153000.00              5.80
# 129                 45                    1  235000.00              2.50
# 96                  38                    1  263358.03              1.18
# 132                 35                    1  533000.00              1.30
# 16                  38                    1  283000.00              0.60
# 56                  30                    1  211000.00              0.80
# 29                  25                    0  262000.00              1.00
# 37                  35                    0  222000.00              1.00
# 14                  50                    0  235000.00              1.30
# 194                 30                    0  395000.00              1.00
# 25                  40                    1  263358.03              1.18
# 233                 25                    1  276000.00              1.30
# 120                 38                    0  133000.00              1.70
# 75                  50                    0  194000.00              1.10
# 104                 25                    0  274000.00              1.20
# 88                  40                    0  283000.00              0.70
# 6                   60                    1  263358.03              1.00
# 86                  30                    0  200000.00              1.20
# 15                  60                    0  265000.00              1.40
# 187                 20                    0  210000.00              1.90
# 131                 45                    0   73000.00              0.70
# 4                   38                    1  263358.03              1.83
# 47                  40                    0  279000.00              0.70
# 128                 40                    1  216000.00              2.30
# 105                 38                    0  451000.00              1.30
# 106                 40                    0  270000.00              1.00
# 58                  40                    0  277000.00              0.70
# 99                  45                    1  362000.00              1.10
# 179                 60                    1  377000.00              1.00
# 90                  55                    0  543000.00              1.00
# 143                 25                    0  189000.00              1.30
# 171                 40                    0  279000.00              0.80
# 39                  45                    1  263358.03              1.18
#
#      serum_sodium  sex  smoking  time
# 119           130    1        0     4
# 138           116    0        0     8
# 10            124    0        0   100
# 49            135    0        0   130
# 74            140    1        0   245
# 48            134    1        0    83
# 124           132    0        0   215
# 45            126    1        0    91
# 127           134    1        0    30
# 1             134    1        0   162
# 162           135    1        0    22
# 107           139    0        0    43
# 33            145    0        0    30
# 24            136    1        1    80
# 178           133    0        0   245
# 102           134    1        0    26
# 129           135    0        0   115
# 96            137    0        0   185
# 132           139    0        0   212
# 16            131    1        1    74
# 56            138    1        0   108
# 29            136    1        1   120
# 37            132    1        0   244
# 14            134    1        0   121
# 194           140    0        0    42
# 25            137    0        0   107
# 233           137    0        0    16
# 120           140    1        0   244
# 75            145    1        1   200
# 104           134    0        0   207
# 88            133    0        0   233
# 6             139    1        0   215
# 86            132    1        1    26
# 15            125    0        0   205
# 187           137    1        0     7
# 131           137    1        0   186
# 4             134    1        0    27
# 47            140    1        1   147
# 128           131    0        0    60
# 105           136    0        0   246
# 106           138    0        0   140
# 58            137    1        1   187
# 99            139    1        1   121
# 179           136    1        0   186
# 90            132    0        0   250
# 143           132    1        1   205
# 171           141    1        0   250
# 39            137    1        0    87

# %%
train_X.to_csv('train.csv',index=0)

# %%
test_X.to_csv('test.csv',index=0)

# %%
plt.figure(figsize=(16,4))
plt.xticks(rotation=90)
train_a_ratio = data[data['DEATH_EVENT'] == 1].groupby(['age']).size()/data.groupby(['age']).size()
ax = sns.barplot(x=train_a_ratio.index, y=train_a_ratio)
ax.set_title("Show Percentage by Age")

print (data['age'].value_counts())
print (train_a_ratio)
plt.show()
# Out:
# 60.000    25
# 65.000    21
# 50.000    21
# 70.000    17
# 55.000    14
# 45.000    12
# 58.000     9
# 53.000     9
# 75.000     9
# 40.000     6
# 85.000     6
# 63.000     6
# 52.000     5
# 62.000     5
# 68.000     5
# 72.000     5
# 42.000     5
# 61.000     4
# 73.000     4
# 80.000     4
# 51.000     3
# 82.000     3
# 59.000     3
# 69.000     3
# 49.000     3
# 46.000     3
# 67.000     2
# 90.000     2
# 66.000     2
# 44.000     2
# 60.667     2
# 78.000     2
# 95.000     2
# 57.000     2
# 41.000     1
# 48.000     1
# 56.000     1
# 86.000     1
# 54.000     1
# 47.000     1
# 64.000     1
# 81.000     1
# 77.000     1
# 43.000     1
# 79.000     1
# 94.000     1
# 87.000     1
# Name: age, dtype: int64
# age
# 40.000         NaN
# 41.000         NaN
# 42.000    0.200000
# 43.000         NaN
# 44.000         NaN
# 45.000    0.083333
# 46.000    0.333333
# 47.000         NaN
# 48.000    1.000000
# 49.000    0.333333
# 50.000    0.285714
# 51.000         NaN
# 52.000         NaN
# 53.000    0.111111
# 54.000    1.000000
# 55.000    0.214286
# 56.000         NaN
# 57.000    0.500000
# 58.000    0.111111
# 59.000    0.666667
# 60.000    0.360000
# 60.667    0.500000
# 61.000         NaN
# 62.000    0.200000
# 63.000         NaN
# 64.000         NaN
# 65.000    0.380952
# 66.000         NaN
# 67.000         NaN
# 68.000    0.400000
# 69.000    0.666667
# 70.000    0.294118
# 72.000    0.600000
# 73.000    0.250000
# 75.000    0.555556
# 77.000         NaN
# 78.000         NaN
# 79.000         NaN
# 80.000    0.500000
# 81.000         NaN
# 82.000    1.000000
# 85.000    0.500000
# 86.000    1.000000
# 87.000    1.000000
# 90.000    0.500000
# 94.000    1.000000
# 95.000    1.000000
# dtype: float64
